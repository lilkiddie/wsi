# %%
from wsi.semeval_utils import generate_sem_eval_2013_no_tokenization
from collections import defaultdict
from wsi.lm_bert import LMBert
from wsi.WSISettings import DEFAULT_PARAMS, WSISettings

# %%
gen = generate_sem_eval_2013_no_tokenization('./resources/SemEval-2013-Task-13-test-data')

# %%
ds_by_target = defaultdict(dict)
for pre, target, post, inst_id in gen:
    lemma_pos = inst_id.rsplit('.', 1)[0]
    ds_by_target[lemma_pos][inst_id] = (pre, target, post)

inst_id_to_sense = {}
gen = ds_by_target.items()

# %%
it = iter(gen)

# %%
lemma_pos, inst_id_to_sentence = next(it)

# %%
lemma_pos, inst_id_to_sentence
# Out:
# ('become.v',
#  {'become.v.1': ("It's no wonder that Wolf has",
#    'become',
#    'a well-paid political consultant.'),
#   'become.v.2': ("Analysts speculate Kaiser's decision will accelerate a race by insurers to avoid",
#    'becoming',
#    'havens for impotent men.'),
#   'become.v.3': ('Lake has two problems: 1) his (inadvertent, he says) failure to sell some energy stocks in 1993, when he',
#    'became',
#    "national security adviser; and 2) Republican alarm that he might be a dangerous lefty, based on his 1970 resignation from the National Security Council over Nixon's invasion of Cambodia, and on his more recent refusal to confirm that Alger Hiss was a staff Soviet spy."),
#   'become.v.4': ('John Longhouser , head of the Aberdeen Proving Ground, retired after an affair he had had five years ago',
#    'became',
#    'public knowledge.'),
#   'become.v.5': (', have',
#    'become',
#    'such tasteless parodies of politicians that I was doubting whether I could pull the lever for Hill.'),
#   'become.v.6': ('In any case, there certainly is no lack of information available about the moguls of technology now as they all',
#    'become',
#    'our current pop icons.'),
#   'become.v.7': ('With a 50 percent divorce rate in America and 3 out of 10 households run by a single parent (three times as many as two decades ago), Once and Again seems poised to',
#    'become',
#    'for joint custody what Thirtysomething was for yuppie angst.'),
#   'become.v.8': ("The WTO's advocates, belatedly realizing that it has",
#    'become',
#    'a political target, are beginning to counter the principal spins against the organization.'),
#   'become.v.9': ('With most plants needing to install control equipment to meet these requirements, it is likely that this approach would lead to installation of controls that',
#    'become',
#    'obsolete and stranded capital investments as additional requirements are promulgated.'),
#   'become.v.10': ('It was when I was a high-school student that I',
#    'became',
#    'convinced of this fact for the first time.'),
#   'become.v.11': ('As he was an author and a public figure who corresponded with a wide circle of literary and artistic friends throughout Europe, the Gothic design of Strawberry Hill',
#    'became',
#    'famous among connoisseurs.'),
#   'become.v.12': ('and in thirty years it',
#    'becomes',
#    "pretty critical i mean my um brother-in-law is like um i mean he's sixty he's not ready to retire but his company is is closing is um is uh closing up"),
#   'become.v.13': ('well we in in in our family have been pretty remiss in trying to uh you know keep track of uh daily finances uh the uh way way back what twelve years ago or something when i got my first computer i did what everybody else does which is to put the whole family budget on the machine and put checks and you know checkbooks and all those kind of thing and we kept that going for about a month and it',
#    'became',
#    'so onerous that we gave up on it'),
#   'become.v.14': ('In this way pachuquesmo, a Mexican subculture,',
#    'became',
#    'known throughout the Southwest.'),
#   'become.v.15': ('Speed of delivery has increasingly',
#    'become',
#    'part of the competitive equation.'),
#   'become.v.16': ('Hang around any schoolyard in Germany or college campus in Indonesia and it',
#    'becomes',
#    "clear that the recording industry's problems with the illegal online distribution of music in the United States pale beside the rampant piracy that goes on overseas."),
#   'become.v.17': ("well and don't you think that you do see more women who are um",
#    'becoming',
#    'part of middle management'),
#   'become.v.18': ("yeah and they should give every teacher a a hundred percent raise that that's the problem is the teachers don't get enough money and anybody who could be a good teacher doesn't want to",
#    'become',
#    "a teacher usually because they don't pay enough i mean when i was in college i did a lot of teaching uh for my degree and uh i got a lot of good out of that and i liked teaching but i really couldn't go into teaching because it was not economically feasible for me to do so"),
#   'become.v.19': ('However clear and meaningful the definition of a case may have been in the past, it',
#    'became',
#    'evident the definition had not kept pace with the changes in the service delivery systems.'),
#   'become.v.20': ('But if the recipient is an autonomous agent such as a bacterium and the incoming molecule is a symbol-sign of a paramecium or an amoeba on the roam and the bacterium swims away and avoids',
#    'becoming',
#    'dinner, that sequence of events seems laden with semantics.'),
#   'become.v.21': ('To make a long story short, she has lied about multiple things since I',
#    'became',
#    'friends with her.'),
#   'become.v.22': ('And although we did not until now think of this secular prayer as the preamble to a new order of nationhood, equality, and democracy, that is what they',
#    'became',
#    '.'),
#   'become.v.23': ('Someone will have a great incentive to sell speedy access, as free access',
#    'becomes',
#    'slower, and find a way to do it.'),
#   'become.v.24': ('Most are simply battle-fatigued and judgment-impaired, trapped in what has',
#    'become',
#    'a journalistic dead end, an untenable profession.'),
#   'become.v.25': ('Anything with a hint of swollen bud', 'became', 'my prey.'),
#   'become.v.26': ('What contemporary travel needs to',
#    'become',
#    'truly convenient are updated versions of Homeric households.'),
#   'become.v.27': ('The better known he',
#    'became',
#    ', the more he burrowed into Cookham backyards and bedrooms.'),
#   'become.v.28': ('Meanwhile, La Brea (the blocks between Wilshire and Melrose) and Beverly Boulevard (between La Brea and Curson) have',
#    'become',
#    'destinations for the stylish locals who are too old for Melrose fashion and too hip for Rodeo.'),
#   'become.v.29': ('Since then, a mass of apartment blocks and hotels has sprung up and the town has',
#    'become',
#    'known as an international fun city.'),
#   'become.v.30': ("Lockheed's reputation was really made during World War II, when the company built both the C-69 Constellation transport (which",
#    'became',
#    'the standard for civil airlines in the immediate post-war period) and, more impressively, the P-38 Lightning fighter.'),
#   'become.v.31': ("Wright's successful petition to Clinton for a better grade",
#    'became',
#    ', in Dan Rather\'s words, an illustration of her "long, often unfriendly, history with Bill Clinton."'),
#   'become.v.32': ('A 7-year-old Queens, N.Y., boy is charged with sexual harassment and suspended from the second grade for kissing a female classmate; within a week, his picture is on the front page of the New York Times . A similar incident involving a 6-year-old schoolboy in North Carolina',
#    'becomes',
#    'a national scandal.'),
#   'become.v.33': ('But he then',
#    'becomes',
#    'a contestant, competing with the more successful guests.'),
#   'become.v.34': ('It quoted a lawyer "familiar with the negotiations" as saying there was a Secret Service agent who had seen Clinton and Lewinsky in a "compromising situation" and that he had',
#    'become',
#    'a government witness.'),
#   'become.v.35': ('And an astonishing number of them are already engaged in all-but-official campaigns, desperate quests to',
#    'become',
#    'an "early favorite."'),
#   'become.v.36': ('(His friends have boasted that without Milliken, Ronald Reagan would not have',
#    'become',
#    'president.)'),
#   'become.v.37': ('He did well in school and',
#    'became',
#    'enthusiastically involved in several activities.'),
#   'become.v.38': ("Her husband couldn't have been more understanding, but his wife's emotionalism was so impervious to logic it",
#    'became',
#    'disturbing.'),
#   'become.v.39': ('He noted that many practices that do not have efficacy or effectiveness studies behind them are adopted and',
#    'become',
#    'guidelines for standard practice.'),
#   'become.v.40': ('Um, well, do you think it also helped when you',
#    'became',
#    'a parent that you naturally wanted to read to your kids?'),
#   'become.v.41': ('We have admired their determination to do their best to prevent another tragedy while preparing to respond if it',
#    'becomes',
#    'necessary.'),
#   'become.v.42': ('Wolf, whose $15,000 per month retainer was just cut to $5,000, urged Gore to condemn President Clinton for his sexual foibles and to',
#    'become',
#    'an "alpha male."'),
#   'become.v.43': ('They can drop out of the entire rat race and',
#    'become',
#    'folk singers or something, or they can belly up to the bar and play in the real world where money is generally the accepted way we keep score.'),
#   'become.v.44': ('The issue will',
#    'become',
#    'more pressing as an estimated 40,000 to 50,000 Chinese, mostly unskilled, come to settle each year.'),
#   'become.v.45': ('None other than Dick Morris complains in the Weekly Standard that the book "',
#    'becomes',
#    'a porn novel," with its heavy focus on presidential sex.'),
#   'become.v.46': ('The Washington Post groaned that the TWA mystery "has',
#    'become',
#    'the aviation equivalent of the Kennedy assassination"--i.e.'),
#   'become.v.47': ('Also, an English professor writes about getting fired and',
#    'becoming',
#    'a carpenter.'),
#   'become.v.48': ('Pop culture prediction: British military clothing will',
#    'become',
#    'hot, hot, hot on the streets of San Francisco, the Village, and West Hollywood.'),
#   'become.v.49': ('But there is one remarkable statistic (which itself is difficult to explain): Since the middle of last year, the falling unemployment rate has',
#    'become',
#    'decoupled from wage increases.'),
#   'become.v.50': ("But even if you haven't noticed Dreamcast before today, it's a safe bet that over the next few months the product is going to",
#    'become',
#    "inescapable, since Sega is in the process of spending tens of millions of dollars on an elaborate marketing campaign that includes, among other things, sponsoring tonight's MTV Video Music Awards."),
#   'become.v.51': ("There was endless hype for the premiere of Felicity's second season--tapes of which had been withheld from the press--because it was to provide the answer to last season's Perils of Pauline -like cliffhanger: Would the New York City college freshman Felicity fly to Berlin with her handsome and intelligent though overly chatty boyfriend Noel or drive home to California with the exceedingly handsome but markedly less intelligent Ben, an ex-crush who had",
#    'become',
#    "her best friend's boyfriend?"),
#   'become.v.52': ('But I have recently',
#    'become',
#    'a parent and wonder how I should react to this type of situation if I were with an inquisitive child.'),
#   'become.v.53': ('Repeat this a number of times, even from day to night and back, and the pile',
#    'becomes',
#    'more and more unstable until possibly one cold spell causes collapse.'),
#   'become.v.54': ("that's right and and it's a terrible thing to do uh and the world our world seems to",
#    'become',
#    "more and more violent all the time by the way i'm a public school administrator so"),
#   'become.v.55': ("oh well right now i'm trying to keep abreast of uh what's going on in Europe you know with all the uh USSR's satellites breaking off and trying to",
#    'become',
#    'independent and then you know European community coming together'),
#   'become.v.56': ('Many African Americans wore an extravagant style of clothing, the baggy pegged pants and jackets with padded shoulders, that later',
#    'became',
#    'known as the zoot suit.'),
#   'become.v.57': ("uh we had bought really it it's it's uh it's just beautiful i just i would be very happy staying in Hawaii and",
#    'becoming',
#    "a beachcomber when i retire which isn't too far off which is something i might wanna consider but uh"),
#   'become.v.58': ('If the tension on the top and bottom thread is too high, the seam puckers and the seam length',
#    'becomes',
#    'less than that of the cloth.'),
#   'become.v.59': ('The US has',
#    'become',
#    'the new 1000 year Reich and wants to annex Iraq, Iran, Korea, everything.'),
#   'become.v.60': ("i think that for so many people that uh the nursing home represent obviously different uh different things and depending on the level of function whereas my you know my grandmother doesn't need need any extra uh camaraderie or anything like that because she gets it from her church or from her friends that come by but uh i've seen a lot of people that don't live near their family or don't have you know significant roots in this in their little community they've been uprooted for some reason or another and they i i think that it would be good for them to be into a situation that would offer them uh oh activities to maintain an active mind because like you say if you just put them in the house and keep them there all day long and they they",
#    'become',
#    "they vegetate and that's"),
#   'become.v.61': ("and even then you know we're really running out of space so i think that that",
#    'became',
#    "that all of a sudden really hit home that there's no longer landfill space in some of the more crowded states"),
#   'become.v.62': ("you know and i've heard people say well you know it's just like the American Civil War will there be a union or not well no it's not the same sort of a thing at all because that the whole Soviet system was put together under total force you know there was no as as we are seeing now with a lot of those areas wanting out of it you know they uh nobody voted you know a lot man those people didn't vote to",
#    'become',
#    'part of the Soviet Union they had no choice'),
#   'become.v.63': ("yeah my mother has made similar statements that she doesn't want to",
#    'become',
#    'a burden to the family you know just put me out to pasture or shoot me or something you know there are the lines that come from her and uh'),
#   'become.v.64': ('On a broader level, conferees agreed that we must work to ensure that both individual state justice communities and the broader national counterpart',
#    'becomes',
#    'more diverse, inclusive and multiculturally competent.'),
#   'become.v.65': ('But how does matter, energy, information, and something else miraculous',
#    'become',
#    'selfish?'),
#   'become.v.66': ('Yet, nondenominational expressions of faith have',
#    'become',
#    'normal in the rituals of the American people.'),
#   'become.v.67': ('Lately, however, I have found that some co-workers have',
#    'become',
#    'upset because I was unable to drop everything and come to their aid immediately.'),
#   'become.v.68': ('Prudie, even if you personally don\'t agree that we are at the point where noncooperation is a virtue, won\'t you admit that at some level of taxation, "noncooperation" with the Internal Revenue Service would',
#    'become',
#    'a civic duty?'),
#   'become.v.69': ('Invented by a Frenchman, the neon sign quickly',
#    'became',
#    'an Americanism.'),
#   'become.v.70': ("In the days that follow, Parry's fixation intensifies, Joe's paranoia correspondingly deepens, and Clarissa",
#    'becomes',
#    'increasingly alienated.'),
#   'become.v.71': ("The woman's cascading hair",
#    'becomes',
#    'a cliff plummeting to the ocean below, while her breasts and upraised knees are hills.'),
#   'become.v.72': ('The local daimyo of Satsuma was so impressed that he started to buy British ships, which',
#    'became',
#    'the foundation of the future Imperial Japanese Navy.'),
#   'become.v.73': ('With aid from the EU, Portugal',
#    'became',
#    'one of the fastest-growing countries in Europe.'),
#   'become.v.74': ("People aren't getting a fraction of the productivity--or the fun--they could, and their computers soon",
#    'become',
#    'merely expensive toys.'),
#   'become.v.75': ('As you probably know by now, Slate will soon',
#    'become',
#    'a paid-subscription site.'),
#   'become.v.76': ("And so all the paradoxes of thrift, widow's cruses, and so on",
#    'become',
#    'irrelevant.'),
#   'become.v.77': ('Unable to subvert the machine to his will and conscience, Octavius, together with the BMI,',
#    'becomes',
#    'the villainous Dr. Octopus.'),
#   'become.v.78': ('This was a local story that',
#    'became',
#    "a national one when Israel's earlier pronouncement that he could not be extradited had appeared to threaten U.S.-Israeli relations."),
#   'become.v.79': ('In dialogic reading, the adult encourages the child to',
#    'become',
#    'a participant in the narrative, even a storyteller.'),
#   'become.v.80': ('setting, where there is the question of training and the link between the screening instruments and the intervention,',
#    'becomes',
#    'problematic.'),
#   'become.v.81': ('Some units whose members had',
#    'become',
#    'separated during the climb attempted to regroup so they could descend together.'),
#   'become.v.82': ('An opinion poll published Monday in the Guardian of London found, surprisingly, that a large proportion of Britons think Australia should ditch the monarchy: Forty percent said it should',
#    'become',
#    'a republic and 34 percent that it should keep the queen as its head of state.'),
#   'become.v.83': ('With respect to existence value, the real problem is that its measurement often',
#    'becomes',
#    'subjective.'),
#   'become.v.84': ('All agreed that Gore is doomed if the treaty',
#    'becomes',
#    'his signature issue.'),
#   'become.v.85': ('Reports suggested Flinn cut her deal at just the right time, since 1) the media were',
#    'becoming',
#    'skeptical of her "carefully orchestrated publicity campaign"; 2) editorialists (e.g.'),
#   'become.v.86': ('He said that some groundwork needed to be laid for a "CWR" (this stands for conventional wisdom reversal, Hunt explained to me) once it',
#    'became',
#    'clear that Bush was going to get the GOP nomination.'),
#   'become.v.87': ('Can travel guides still gently educate their readers, or have they merely',
#    'become',
#    'handmaidens, shuttling readers from one over-visited landmark to the next?'),
#   'become.v.88': ('Columbine had the great hook: kids, especially the unfortunate girl who professed her belief in God and',
#    'became',
#    'an instant martyr.'),
#   'become.v.89': ('Lennox Lewis defeated Evander Holyfield to',
#    'become',
#    'the world heavyweight boxing champion.'),
#   'become.v.90': ('The current approach is inefficient and ineffective, imposing unnecessarily high costs due to: (1) stranded capital investments from the installation of controls that later',
#    'become',
#    'obsolete when additional requirements are promulgated; (2) reduced lead time for complying with those requirements; (3) limited or non-existent flexibility for emissions trading to allow cost-efficient control options; and (4) a reliance upon lengthy, expensive, and uncertain litigation to sort out regulatory ambiguity and compliance with the law.'),
#   'become.v.91': ('Eventually I concluded even the correct word would have',
#    'become',
#    'maddening from repetition, unrelieved by a synonym or circumlocution.'),
#   'become.v.92': ('I',
#    'became',
#    'convinced that a strong connection exists between the way that we decorate our homes and the way that we dress ourselves.'),
#   'become.v.93': ('The information collections in the rule will not',
#    'become',
#    'effective until OMB approval is obtained and an OMB control number has been issued.'),
#   'become.v.94': ("well i think that you know brand name products that we've",
#    'become',
#    'familiar with have in most cases you know gotten better i think that we have a problem in this country with consumer protection laws and the lack thereof'),
#   'become.v.95': ("actually i've been involved in recycling for long before it",
#    'became',
#    'fashionable back when i was in graduate school i did all of the recycling of the um paper from the computer center and uh in fact i think i was the first person in our department to have my thesis published on recyclable paper recycled paper'),
#   'become.v.96': ('it almost',
#    'becomes',
#    "more more cost you know to much cost and more trouble than it's worth you know to to put somebody like that to death or something that you know"),
#   'become.v.97': ('i think so and i feel like you know like President Bush Bush has mentioned quite often that we are trying to',
#    'become',
#    'a kinder and gentler nation and it does begin with the families at home'),
#   'become.v.98': ('The narrative of the Fifth Sun is based on an Aztec myth that has',
#    'become',
#    'an important cultural expression commonly incorporated into Chicano cultural events.'),
#   'become.v.99': ('As the cross elasticities become larger, the efficient discount levels move closer to the ECP level and the associated welfare gains available',
#    'become',
#    'quite small.'),
#   'become.v.100': ("and you know he did not finish high school he just went straight straight to Westminster s o i never really remember having lived at home with him and after he did get out of college it was not long he before he uh just moved to New York City knowing that that's where he had to live to quote unquote make it in the music world and um",
#    'became',
#    "a music critic and that probably puts us somewhere around the early sixties uh when he was doing that i've seen that date a good bit on the uh on some of the albums because he would typically uh sign and date everything that i think everything that he owned he did that with but certainly all of his albums and all of the music uh he had signed and dated")})

# %%
model = LMBert(0, 'bert-large-uncased', 10)
# Out:
# lemmatizing vocab: 100%|████████████████████████████████████████████████████████| 30522/30522 [00:09<00:00, 3058.22it/s]

# %%
settings = DEFAULT_PARAMS._asdict()
settings = WSISettings(**settings)

# %%
obj = model.predict_sent_substitute_representatives(inst_id_to_sentence, settings)

# %%
len(obj['become.v.1'][3])
# Out:
# 13

# %%
import torch
import numpy as np
device = torch.device('cuda:0')

# %%
patterns = settings.patterns
n_patterns = len(patterns)
pattern_str, pattern_w = list(zip(*patterns))
pattern_w = torch.from_numpy(np.array(pattern_w, dtype=np.float32).reshape(-1, 1)).to(device=device)

# %%
sorted_by_len = sorted(inst_id_to_sentence.items(), key=lambda x: len(x[1][0]) + len(x[1][2]))

# %%
def get_batches(from_iter, group_size):
    ret = []
    for x in from_iter:
        ret.append(x)
        if len(ret) == group_size:
            yield ret
            ret = []
    if ret:
        yield ret

# %%
gen = get_batches(sorted_by_len, 10 // n_patterns)
batch = next(gen)

# %%
batch_sents = []
for inst_id, (pre, target, post) in batch:
    for pattern in pattern_str:
        batch_sents.append(model.format_sentence_to_pattern(pre, target, post, pattern))

# %%
tokenized_sents_vocab_idx = [model.tokenizer.convert_tokens_to_ids(x[0]) for x in batch_sents]
max_len = max(len(x) for x in tokenized_sents_vocab_idx)
batch_input = np.zeros((len(tokenized_sents_vocab_idx), max_len), dtype=np.longlong)
for idx, vals in enumerate(tokenized_sents_vocab_idx):
    batch_input[idx, 0:len(vals)] = vals
torch_input_ids = torch.tensor(batch_input, dtype=torch.long).to(device=device)
torch_mask = torch_input_ids != 0
logits_all_tokens = model.bert(torch_input_ids, attention_mask=torch_mask)

# %%
logits_target_tokens = torch.zeros((len(batch_sents), logits_all_tokens.shape[2])).to(device)

# %%
logits_target_tokens_joint_patt = torch.zeros(
                    (len(batch_sents) // n_patterns, logits_target_tokens.shape[1])).to(
                    device)

# %%
for i in range(0, len(batch_sents), n_patterns):
    logits_target_tokens_joint_patt[i // n_patterns, :] = (
            logits_target_tokens[i:i + n_patterns, :] * pattern_w).sum(0)

# %%
pre_softmax = torch.matmul(
                    logits_target_tokens_joint_patt,
                    model.bert.bert.embeddings.word_embeddings.weight.transpose(0, 1))

# %%
topk_vals, topk_idxs = torch.topk(pre_softmax, settings.prediction_cutoff, -1)

# %%
probs_batch = torch.softmax(topk_vals, -1).detach().cpu().numpy()
topk_idxs_batch = topk_idxs.detach().cpu().numpy()

# %%
(inst_id, (pre, target, post)), probs, topk_idxs = list(zip(batch, probs_batch, topk_idxs_batch))[0]

# %%
pre, target, post
# Out:
# ('Anything with a hint of swollen bud', 'became', 'my prey.')

# %%
lemma = target.lower() if settings.disable_lemmatization else model._get_lemma(target.lower())
probs = probs.copy()
target_vocab = model.original_vocab if settings.disable_lemmatization else model.lemmatized_vocab

# %%
res = {}

# %%
for i in range(settings.prediction_cutoff):
    if target_vocab[topk_idxs[i]] == lemma:
        probs[i] = 0
probs /= np.sum(probs)

new_samples = list(
    np.random.choice(topk_idxs, settings.n_represents * settings.n_samples_per_rep,
                     p=probs))
new_reps = []
for i in range(settings.n_represents):
    new_rep = {}
    for j in range(settings.n_samples_per_rep):
        new_sample = target_vocab[new_samples.pop()]
        new_rep[new_sample] = 1  # rep.get(new_sample, 0) + 1
    new_reps.append(new_rep)
res[inst_id] = new_reps

# %%
obj = (['В',
  'картине',
  'Бегство',
  'мистера',
  'Мак-Кинли',
  'есть',
  'крохотный',
  'эпизод',
  'КОГДА',
  'развратного'],
 'вида',
 ['субъект', 'предлагает', 'Банионису', 'двух', 'нимфеток'])

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

# %%
tokenizer = AutoTokenizer.from_pretrained("ai-forever/ruRoberta-large")
model = AutoModelForMaskedLM.from_pretrained("ai-forever/ruRoberta-large")
# Out:
# vocab.json:   0%|          | 0.00/1.81M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# /mnt/c/Users/d2deb/Taxonomy enrichment/env/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
tokenizer.tokenize()
# Out:
# ['ÐŁÑĢÐ¸Ð²ÐµÑĤ', ',', 'ĠÐºÐ°Ðº', 'ĠÐ´ÐµÐ»Ð°', '?']

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/squizycake/.local/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/squizycake/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/squizycake/.local/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: tzdata>=2022.1 in /home/squizycake/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/squizycake/.local/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from razdel import sentenize, tokenize
import pymorphy3
import string
from copy import copy
punctuations = list(string.punctuation)
# Out:
# /tmp/ipykernel_207462/257316219.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
punctuations.append('...')

# %%
pm = pymorphy3.MorphAnalyzer()

# %%
df = pd.read_csv('resources/russe-wsi-kit-fixed_datasets/data/main/bts-rnc/train.csv', sep='\t')

# %%
df
# Out:
#       context_id   word  gold_sense_id  predict_sense_id    positions  \
# 0              1  балка              1               NaN        90-95
# 1              2  балка              1               NaN        69-74
# 2              3  балка              1               NaN      115-122
# 3              4  балка              1               NaN        85-91
# 4              5  балка              1               NaN        66-71
# ...          ...    ...            ...               ...          ...
# 3486        3487  штамп              4               NaN  59-66,81-87
# 3487        3488  штамп              4               NaN        85-91
# 3488        3489  штамп              4               NaN  30-37,71-78
# 3489        3490  штамп              4               NaN      107-113
# 3490        3491  штамп              4               NaN       95-101
#
#                                                 context
# 0     маленькой комнаты. Он был очень высок, наклони...
# 1     Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2     равнозначно обеспечивает и меланхоличную езду....
# 3     верхняя часть закрыта, замкнута, многократно о...
# 4     по телевизору: наши гол забили, я вскочил от р...
# ...                                                 ...
# 3486  дурак, но партию свою отрабатывал точно, по ус...
# 3487  дело... получается, мыслить и выражать свое мн...
# 3488  , что актер должен иметь пять штампов-клише "п...
# 3489  сегодняшний день в системе негосударственного ...
# 3490  молиться на Брукхаймера… …В «Пираты Карибского...
#
# [3491 rows x 6 columns]

# %%
pos = df.iloc[3486]['positions']

# %%
start, end = map(int, pos.split(',')[0].split('-'))

# %%
start, end, text = list(sentenize(df['context'][1]))[0]

# %%
start, end
# Out:
# (0, 25)

# %%
context = df.iloc[15].context
word = df.iloc[21].word
word, context
# Out:
# ('балка',
#  '!.. Дрок упорно таскал к месту, облюбованному им для своей постройки, то старые балки, то стропила, то доски… Наконец, завел тачку и начал издалека привозить дикий')

# %%
df.iloc[0]
# Out:
# context_id                                                          1
# word                                                            балка
# gold_sense_id                                                       1
# predict_sense_id                                                  NaN
# positions                                                       90-95
# context             маленькой комнаты. Он был очень высок, наклони...
# Name: 0, dtype: object

# %%
def russe_wsi_gen(path):
    df = pd.read_csv(path, sep='\t')
    prev = None
    idx = 0
    for index in df.index:
        word = df['word'][index]
        # print(prev, target)
        if word != prev:
            idx = 1
        pos = df['positions'][index]
        start, end = map(int, pos.split(',')[0].split('-'))
        for sent in sentenize(df['context'][index]):
            start_, end_, text = sent
            # print(start_, end_, start, end, text)
            if not start_ <= start <= end_:
                continue
            start -= start_
            end -= start_
            pre, target, post = text[:start], text[start:end], text[end:]
            yield (pre, target, post, df['word'][index] + f'.{idx}')
            prev = word
            idx += 1

# %%
gen = russe_wsi_gen('resources/russe-wsi-kit-fixed_datasets/data/main/bts-rnc/train.csv')

# %%
from collections import defaultdict

# %%
ds_by_target = defaultdict(dict)
for pre, target, post, inst_id in gen:
    lemma_pos = inst_id.rsplit('.', 1)[0]
    ds_by_target[lemma_pos][inst_id] = (pre, target, post)

# %%
ds_by_target
# Out:
# defaultdict(dict,
#             {'балка': {'балка.1': ('Он был очень высок, наклонил голову, словно подпирая плечом потолочную ',
#                'балку',
#                ', посмотрел на Сьянову серьезными черными глазами.'),
#               'балка.2': ('Он выползти на улицу успел, а на Золоткова ',
#                'балка',
#                ' обрушилась.'),
#               'балка.3': ('Цельнометаллическое тело, усиленное передними и задними поперечными ',
#                'балками',
#                ', наряду с работой подвески превращает машину в глыбу, всей плоскостью вросшую в'),
#               'балка.4': ('верхняя часть закрыта, замкнута, многократно обрамлена и в конце концов, как тяжёлой ',
#                'балкой',
#                ', придавлена широким многоступенчатым карнизом.'),
#               'балка.5': ('по телевизору: наши гол забили, я вскочил от радости и врезался в ',
#                'балку',
#                ', поскольку дело было в низенькой мансарде.'),
#               'балка.6': ('вы взглянете на стену нашего театра возле ЦУМа, то увидите торчащие железные ',
#                'балки',
#                '— это стяжки, которые пронзают здание насквозь.'),
#               'балка.7': ('На продольной ',
#                'балке',
#                ' 14 рамы 7 смонтирован кронштейн 15 с вертикальной регулировочной тягой 16, на'),
#               'балка.8': ('Да в одни и те же места: либо под ',
#                'балки',
#                ', либо под изгиб печной трубы...'),
#               'балка.9': ('активно шла работа по переработке металлолома, который затем используется для изготовления арматуры,',
#                'балок',
#                ' и труб.'),
#               'балка.10': ('основания, находится место, где частенько собираются подростки – рисунки граффити, пошлые надписи на ',
#                'балках',
#                ' и несущей опоре, банки пива...'),
#               'балка.11': ('ценим историческую архитектуру и бережно подходим ко всем материалам: собираем старые деревянные ',
#                'балки',
#                ', чугунные колонны, кирпичи.'),
#               'балка.12': ('По вагонам, по колесным парам, надрессорным ',
#                'балкам',
#                ' и т.д. сегодня уже есть несколько покупателей, но в ряде случаев'),
#               'балка.13': ('Те же опорные ',
#                'балки',
#                '-- мембраны, те же лифты -- ионные каналы клеток, те же входные двери -- рецепторы,'),
#               'балка.14': (', удары колёс о стыки рельсов стали звонче , и мимо окна понеслись ржавые ',
#                'балки',
#                ' моста , за которыми была видна широкая голубая полоса неизвестной реки .'),
#               'балка.15': ('. Глушков работал с безумным исступлением , и только безумие помогло ему ворочать тяжёлые ',
#                'балки',
#                ', совершить работу , которая была бы по силам десятерым .'),
#               'балка.16': ('Дрок упорно таскал к месту, облюбованному им для своей постройки, то старые ',
#                'балки',
#                ', то стропила, то доски…'),
#               'балка.17': ('-Рига, через реку Вазуза, местный житель, спустившийся прополоскать белье, увидел подвешенное на ',
#                'балке',
#                ' тело неизвестного парня и вызвал полицию.'),
#               'балка.18': ('Основной на сегодня является версия, что причиной аварии стало обрушение ',
#                'балки',
#                ' перекрытия в связи с «усталостью металла».'),
#               'балка.19': ('Есть дома, особенно небольшие, с раскрошившейся крышей, из-под которой обрушились ',
#                'балки',
#                ' и доски.'),
#               'балка.20': ('на Пресне ломали старинный дом: с третьего яруса с ней упал, с ',
#                'балками',
#                ' рухнулся, а опустило безо вреда, ни царапины!'),
#               'балка.21': (', лазил на горящие здания; огнем опалило ему волосы; едва не задавило рухнувшей ',
#                'балкою',
#                '.'),
#               'балка.22': ('-- Добавить ',
#                'балку',
#                ' ко второму концу балки E 1 и ко второму концу балки E 2 ;'),
#               'балка.23': ('Жёлтая электролампа под колпаком свешивалась с деревянной ',
#                'балки',
#                ', как самоубийца .'),
#               'балка.24': ('во весь рост только в таком случае, если предварительно позаботился отойти от ',
#                'балки',
#                ' и стать в самом глубоком месте пола.'),
#               'балка.25': ('Небоскреб состоит из фундамента, стального каркаса из колонн и ',
#                'балок',
#                ' над землей и стен на завесах, прикрепленных к балкам.'),
#               'балка.26': ('из колонн и ',
#                'балок',
#                ' над землей и стен на завесах, прикрепленных к балкам.'),
#               'балка.27': ('По словам губернатора, такой вывод можно сделать из-за "разрушения основной титановой ',
#                'балки',
#                '.'),
#               'балка.28': ('домов – полностью снесен шифер с крыш, с одного дома снесена крыша с ',
#                'балками',
#                ', в местном детском саду повреждено 20% кровли и частично были выбиты стекла.'),
#               'балка.29': ('При их трепетном свете можно было разглядеть деревянные ',
#                'балки',
#                ' под крышей и наивную роспись на стенах: доброго пастыря с овцой на'),
#               'балка.30': ('Талисман «Металлурга» лисенок что есть силы колотит в подвешенную металлическую ',
#                'балку',
#                '(это такое ноу-хау в Магнитогорске, вместо паровозного гудка), а герой утопает в'),
#               'балка.31': ('Денег на стойки и ',
#                'балки',
#                ' для детей надо немного.'),
#               'балка.32': ('таких случаях часто наступает тот самый «реактивный момент», когда задний винт сносит ',
#                'балку',
#                '.'),
#               'балка.33': ('Потолка над башней не было, он давно обвалился, лишь одна полусгнившая ',
#                'балка',
#                ', как пушка, торчала из каменной стены.'),
#               'балка.34': ('... Я не хочу делать никаких официальных заявлений, но если бы действительно та ',
#                'балка',
#                ' взорвалась, самолет бы развалился прямо в воздухе на мелкие куски.'),
#               'балка.35': ('Цветаевой, «она висела невысоко над полом, на гвозде, вбитом в поперечную потолочную ',
#                'балку',
#                ', на тонком крепком шнуре».'),
#               'балка.36': ('* Add Beam E2 F -- Добавить ',
#                'балку',
#                ' ко второму концу балки E 1 и к свободному узлу F . Параметры'),
#               'балка.37': ('Стоявшую на двутавровых ',
#                'балках',
#                ' в самом море деревянную кофейню, вычурно раскрашенную и носившую шутливое название «Поплавок»,'),
#               'балка.38': ('Когда стены срубят и проложат потолочные ',
#                'балки',
#                ', матицы, опять плотникам угощенье: «матешно».'),
#               'балка.39': ('Старая грязь и копоть висела на ',
#                'балках',
#                ' махрами, пахло сыростью и мазутом, разреженный свет осени мертво сиял на механизмах.'),
#               'балка.40': ('Теперь не найти консервов, но много по ',
#                'балкам',
#                ' и по канавам ржавых жестянок, свистящих дырьями на ветру.'),
#               'балка.41': ('Была нарушена технология изготовления ',
#                'балки',
#                ', несущей покрытие здания».'),
#               'балка.42': ('светлые тона, выделяя кирпичный цоколь, подчеркивая линию крыши и умеренно оттеняя деревянные ',
#                'балки',
#                '.'),
#               'балка.43': ('Во Франции материалы берут прямо у природы: грубые каменные стены, деревянные ',
#                'балки',
#                ' потолка, керамическая и деревянная посуда.'),
#               'балка.44': ('. По словам Серебренникова, там «катастрофа на катастрофе»: протекает крыша, старые коммуникации, сгнившие ',
#                'балки',
#                '.'),
#               'балка.45': ('просторном гулком плохо освещенном здании уже вовсю снуют строители, лежат огромные железные ',
#                'балки',
#                ', слышны удары инструментов и скрежет машины для сварки.'),
#               'балка.46': ('закрутились, свились в сизом и черном дыму, устремляясь на потолок, к смолистым ',
#                'балкам',
#                ' истопки.'),
#               'балка.47': ('Американцы же любят вспоминать уже ставшую легендой в авиационных кругах «нашу ',
#                'балку',
#                '»: с этого года все поперечные балки – основа для шасси – для самолетов семейства'),
#               'балка.48': ('Но при этом нельзя затрагивать ',
#                'балки',
#                ' каркаса, расположенные под потолком, и колонны (см. схемы).'),
#               'балка.49': ('можно остановиться как в классическом номере, так и в «эстонском», с деревянными ',
#                'балками',
#                ', сводчатыми потолками, плетеными ковриками и проч.'),
#               'балка.50': ('плед и вздрагивала при всякой молнии, освещавшей небо, при всяком треске валившихся ',
#                'балок',
#                '.'),
#               'балка.51': ('Например, в кораблестроении трёхмерный корпус судна рассматривают в виде одномерной ',
#                'балки',
#                ', для которой уже давно существуют методики расчёта.'),
#               'балка.52': ('автотранспорта по мосту: дают возможность грузовикам быстро отвозить поднятые из воды бетонные ',
#                'балки',
#                '.'),
#               'балка.53': (', ЗПУ и пулемета стрелять по фюзеляжу гораздо сподручнее, чем в узкую хвостовую ',
#                'балку',
#                '.'),
#               'балка.54': ('Из-за таяния снега и грунтовых вод несущие ',
#                'балки',
#                ' исторического сооружения серьезно повредились.'),
#               'балка.55': ('и к первому концу ', 'балки', ' E 2 ;'),
#               'балка.56': ('опытный, как другие, чуть-чуть взял руля не туда, заднее колесо заскользило по ',
#                'балке',
#                ', и грузовик провалился, повиснув карданом на одной из балок и, по счастью,'),
#               'балка.57': ('Whelen HHS 2200, 50 динамиков-громкоговорителей той же фирмы и 25 светодиодных ',
#                'балок',
#                '(оснащение не менее 16 светомодулей).'),
#               'балка.58': ('Прогнившие ',
#                'балки',
#                ' оклеены цветными фотографиями из журналов.'),
#               'балка.59': ('Пространство багажного отделения несколько ограничено расположенной поперек кузова ',
#                'балкой',
#                ' жесткости.'),
#               'балка.60': ('Он метнул нож, который воткнулся в ',
#                'балку',
#                ' за спиной отца: «Ты хотел этой смерти?'),
#               'балка.61': ('Я вытащил цепь и, обмотав ее вокруг железной ',
#                'балки',
#                ', повесил замок.'),
#               'балка.62': ('Крошечные окна, низкий, кривой потолок с ',
#                'балками',
#                ' внутрь, известковые стены, синие от сырости, узенькая железная кровать и стол с'),
#               'балка.63': ('Весной текущего года было обращено внимание на плохое состояние ',
#                'балок',
#                ' на колокольне Ивана Великого, на которых висят колокола, в так называемой Филаретовой'),
#               'балка.64': ('И я увидела мужа, лежащего среди какого-то хлама, придавленного тяжелой деревянной ',
#                'балкой',
#                '.'),
#               'балка.65': ('-',
#                '-Балк',
#                'а, она и в Африке -- балка железобетонная, -- начал свое выступление с шутки Александр'),
#               'балка.66': ('К потолочным ',
#                'балкам',
#                ' подвешены были чучела странных зверей, из которых Жихарь мог узнать (и то'),
#               'балка.67': ('В задней части автомобиля были установлены ',
#                'балки',
#                ' большего объема для защиты салона.'),
#               'балка.68': ('Оно состоит из деревянных ', 'балок', '...'),
#               'балка.69': ('* необходима минимизация весов рёбер ( или масс ',
#                'балок',
#                ');'),
#               'балка.70': ('Упала, допустим, пожарному ',
#                'балка',
#                ' на ногу, нога осталась целой.'),
#               'балка.71': ('и годовалая девочка висели рядком, веревки были привязаны к специально вбитым в ',
#                'балку',
#                ' крюкам.'),
#               'балка.72': ('Срубленная винтом хвостовая ',
#                'балка',
#                ' говорит о том, что машина попала в сверхэкстремальную ситуацию, двигатели и винты'),
#               'балка.73': ('Он не нашел возможным прикрепить к потолку дуговые лампы вследствие ветхости ',
#                'балок',
#                '.'),
#               'балка.74': ('А у потолка, в привязанном к ',
#                'балке',
#                ' мешочке, оказалась окаменевшая мука, спрятанная от мышей.'),
#               'балка.75': ('Рождественские базары, многоярусная елка из металлических ',
#                'балок',
#                '(по словам местных жителей, «толерантная уступка мусульманам»), стайки отдыхающих школяров и моросящий'),
#               'балка.76': ('Под потолком - квадраты из деревянных ',
#                'балок',
#                '.'),
#               'балка.77': ('Мощные, почерневшие от времени деревянные ',
#                'балки',
#                '.'),
#               'балка.78': ('Больше терпеть было невозможно: дьякон закричал и, прыгая через какие-то ',
#                'балки',
#                ', печи, кирпичи, кинулся сквозь перелыгинский дом.'),
#               'балка.79': ('Первая -- длинная ',
#                'балка',
#                ' на высоте 365 метров, которая выступает над рестораном «Седьмое небо».'),
#               'балка.80': ('Еще будучи студентом, принимал активное участие в расчетах армированных конструкций опор,',
#                'балок',
#                ' и плит.'),
#               'балка.81': ('Второй конец этой веревки перекидывали через ',
#                'балку',
#                ' под потолком, кролика слегка подтягивали и, вручив ему второй конец веревки, отпускали.'),
#               'балка.82': ('Волчье логово В Глубокую ',
#                'балку',
#                ' пойти -- за топливом?..'),
#               'балка.83': ('на обозной повозке, я приближался к своей батарее, расположенной где-то в степной ',
#                'балке',
#                '.'),
#               'балка.84': ('До вечера за бугром в терновой ',
#                'балке',
#                ' погромыхивали выстрелы.'),
#               'балка.85': ('2003 году часть асбестовых отходов была вывезена на полигон ТБО в Первомайской ',
#                'балке',
#                '.'),
#               'балка.86': ('Дули ветры по межам, по невидимому кустарнику ',
#                'балок',
#                ', по щебнистым пустырям там, где раньше были хутора, скошенные снарядами по дорогам,'),
#               'балка.87': ('Цепь стояла на опушке леса перед спускающейся голой ',
#                'балкой',
#                '.'),
#               'балка.88': ('Нужно решить по «Золотой ',
#                'балке',
#                '» вопрос землеотвода.'),
#               'балка.89': ('сошелся, до сих пор на Руси предостаточно и ведьминых владений - яров, рощ,',
#                'балок',
#                ', хребтов...'),
#               'балка.90': ('через два часа в Ялте, а теперь я через два часа... в ',
#                'балке',
#                ', если не добыл пропуска!'),
#               'балка.91': ('Регулярный отвал крупных фракций щебня в районе Васильевской ',
#                'балки',
#                ' в декабре прошлого года привел к мощному оползню – под грудой камней оказался'),
#               'балка.92': ('Ближайший тыл позиции, ',
#                'балка',
#                ' Мокрая Мечетка с лежащими на дне балки селами Городище и Уваровка, давал надежное укрытие от огня, но не был'),
#               'балка.93': ('-- Да есть ли еще пасека? -- усомнился он, уже подходя к ',
#                'балке',
#                '.'),
#               'балка.94': ('межевых столба весною этого года перенесены в Калиновом Углу по обеим сторонам ',
#                'балки',
#                '?'),
#               'балка.95': ('гск румын, 5, 6 и 8 кавбригад румын продолжал контратаки в направлении ',
#                'Балки',
#                ', Нв.'),
#               'балка.96': ('Но вот коляска выбралась из последней ',
#                'балки',
#                ' и наконец взъехала на почтовый большак, по которому до города оставалось не'),
#               'балка.97': ('15 сд занимала рубеж обороны Цыгановка,',
#                'балка',
#                ' Московска, балка Вошивая, (иск.)'),
#               'балка.98': ('Пять дней Татьяна Мирных ночевала в ',
#                'балке',
#                ' и ждала помощи.'),
#               'балка.99': ('Партия спустилась под гору и показалась на вершине ближайшей ',
#                'балки',
#                ' справа и стала спускаться вниз.'),
#               'балка.100': ('в машину, хозяйка убежала в дом, а немцы, свернув на съезд в ',
#                'балку',
#                ', поехали в жандармерию.'),
#               'балка.101': ('2) при подработке оврага или ',
#                'балки',
#                ' в направлении перпендикулярном тальвегу, следует выбирать направление движения забоя в плане таким'),
#               'балка.102': (', потревоженного нашим ранним бегом, и видом длинных голубых теней, теряющихся в неглубоких ',
#                'балках',
#                '.'),
#               'балка.103': ('мимо земляных подвалов, где хранился керосин, к конторе, стоявшей подальше, у самой «',
#                'балки',
#                '», на спуске к берегу.'),
#               'балка.104': ('Грозила степная весенняя распутица; в каждом ярке и каждой ',
#                'балке',
#                '-- шумные потоки снеговой воды.'),
#               'балка.105': ('глубока, что, отбежав триста-четыреста шагов, девушки не могли уже видеть ни ',
#                'балки',
#                ', ни реки, ни леса -- степь поглотила все.'),
#               'балка.106': ('Выскакиваю чуть вверх по склону, выглядываю из воронки и вижу: по дну ',
#                'балки',
#                ' к пещере идет вода.'),
#               'балка.107': ('Петька стремительно скатился в ',
#                'балку',
#                ', Григорий за ним.'),
#               'балка.108': ('- Снег таял постепенно и уходил не по замерзшей земле в ',
#                'балки',
#                ', а в почву, - пояснили специалисты.'),
#               'балка.109': ('Напомним: две недели назад, кроме того, в верховьях ',
#                'балки',
#                ' произошел пожар, сгорели гектары можжевельника и фисташки.'),
#               'балка.110': ('И машину подломали , вверх торманом в ',
#                'балку',
#                ' летел .'),
#               'балка.111': ('», к юго-западу от бывшего имения «Грезы» в зарослях кустарника и деревьев, в ',
#                'балке',
#                ', немецкие палачи устроили два колодца смерти...'),
#               'балка.112': ('В устье ',
#                'балки',
#                ', чуть поднявшись на взгорок, в тени Тимофей лег отдохнуть.'),
#               'балка.113': ('Вблизи же, перед высотой и по скатам ',
#                'балок',
#                ', медленным широким полукольцом танки все теснее охватывали берег.'),
#               'балка.114': ('Вставало зарево, освещая склоны холмов, изрезанные падинами да ',
#                'балками',
#                '.'),
#               'балка.115': ('За высотой, на южном берегу реки, левее станицы, на том пространстве перед ',
#                'балкой',
#                ', вчера отрезанном немцами, где недавно ожили несколько орудий, несколько противотанковых ружей и'),
#               'балка.116': ('Всю ночь всей семьею искали они по ',
#                'балкам',
#                ', по лесным чащам.'),
#               'балка.117': ('Не допускать скопления артиллерии в ',
#                'балках',
#                ', ущельях, на переправах, являясь мишенью для мелких групп танков и автоматчиков благодаря'),
#               'балка.118': ('-- Потом Некульев и Арина шли в степь, спускались в ',
#                'балку',
#                ', где наверху склоняли головы солнц подсолнухов, а внизу пересвистывались и замирали неподвижно,'),
#               'балка.119': ('. Наконец полицейского не стало видно: за домом Шевцовых начинался крутой спуск к ',
#                'балке',
#                '.')},
#              'вид': {'вид.1': ('Однако судебный спор «Ландрина» с Роспатентом по охране внешнего ',
#                'вида',
#                ' Raffaello продолжается.'),
#               'вид.2': ('дизельным двигателем и другими современными механизмами, не оставили без внимания и внешний ',
#                'вид',
#                '.'),
#               'вид.3': ('Я имел ',
#                'вид',
#                ' ученика, державшего трудный экзамен перед ареопагом строгих профессоров.'),
#               'вид.4': ('- Остафьев отвечал с расстановкой, тоже, как и господин Голядкин, наблюдая немного таинственный ',
#                'вид',
#                ', подергивая немного бровями, смотря в землю, стараясь попасть в надлежащий тон и,'),
#               'вид.5': ('Параметрическое уравнение прямой линии имеет следующий ',
#                'вид',
#                ': <formula>, где X, Y, Z -- координаты точки на прямой;'),
#               'вид.6': ('Природа Кавказа и Азиатской Турции;',
#                'вид',
#                ' убитых и раненых; затруднения и усталость походной жизни; возможность опасности, которую Пушкин'),
#               'вид.7': ('Само оборудование площадок изменит свой ',
#                'вид',
#                '.'),
#               'вид.8': ('Маринетти явился ко мне с газетой н руках и с грозным ',
#                'видом',
#                '.'),
#               'вид.9': ('Артюшка, вдохновляясь собственной фантазией, вызванной желанием представить жизнь арапчонка в самом ужасном ',
#                'виде',
#                '.'),
#               'вид.10': ('Его фигурке типичного французского буржуа с козлиной бородкой это переодевание воинственного ',
#                'вида',
#                ' не придавало, но зато пришлось по вкусу французским солдатам: народ они опасный'),
#               'вид.11': ('Как я теперь буду оправдываться перед Коляном за потерю товарного ',
#                'вида',
#                ' машины, за унизительную пробежку в тапочках, за все наши наивные приготовления?'),
#               'вид.12': ('хозяйственных построек в поселении не только веселили глаз, но и радовали душу ',
#                'видом',
#                ' обихоженного человеческого жилья.'),
#               'вид.13': ('от мышей они со всех сторон были обрезаны косою, что придавало им ',
#                'вид',
#                ' особенной правильности.'),
#               'вид.14': ('РАЦИОНАЛЬНАЯ ПСИХОТЕРАПИЯ Первое, что бросается в глаза при входе в корпус, — «гражданский»',
#                'вид',
#                ' Вагнера.'),
#               'вид.15': ('Силы, казалось, оставили ее; она имела ',
#                'вид',
#                ' восковой фигуры, с полузакрытыми, потухшими глазами.'),
#               'вид.16': ('И, как бы дополняя нелюдимый ',
#                'вид',
#                ', из-под полы пиджака выглядывает финка в кожаных ножнах.'),
#               'вид.17': ('безошибочно можно было заключить не столько по нарядному платью, сколько по величественному ',
#                'виду',
#                ' и осанке, и, подойдя к бричке, спросил: «Кто здесь?»'),
#               'вид.18': ('Фон Верден (обращаясь к Карпову с ',
#                'видом',
#                ' недоумения и язвительной усмешкой).'),
#               'вид.19': ('пор, как Иваницкий в первый раз увидел Калерию, и все приняло другой ',
#                'вид',
#                ' в доме.'),
#               'вид.20': ('Он, видимо, смягчился, но старался скрывать это смягчение нахмуренным ',
#                'видом',
#                '.'),
#               'вид.21': ('Еще мгновение -- он растерзает, задушит Эмму своими иссохшими руками.',
#                'Вид',
#                ' человека приводит его в бешенство; он видит в нем своего врага, и'),
#               'вид.22': ('Люди страшного ',
#                'вида',
#                ', в разодранной одежде, толпились вокруг повозки при свете факелов.'),
#               'вид.23': ('и огромным ртом, то в ',
#                'виде',
#                ' хохла с пером, то наконец в виде фаллоса; следует думать, что этими фигурами далеко не исчерпывается запас символов для'),
#               'вид.24': ('приближенных значений sin П(a), sin П(b) и проч. примут следующий ',
#                'вид',
#                ': <formula>.'),
#               'вид.25': ('группа депутатов «Единой России» внесла законопроект, ужесточающий наказание за вождение в нетрезвом ',
#                'виде',
#                '.'),
#               'вид.26': ('Поэт представлен в шароварах а-ля "новый русский на отдыхе" и жуткого ',
#                'вида',
#                ' ботах.'),
#               'вид.27': (', как это ему так удалось нарушителя поймать, да еще в таком закамуфлированном ',
#                'виде',
#                '.'),
#               'вид.28': ('Ответ на этот вопрос сложно сформулировать в печатогеничном ',
#                'виде',
#                '.'),
#               'вид.29': ('даже иракскими террористами, обезглавливающими американца, - приговор войне, попав на которую, нормальные с ',
#                'виду',
#                ' парни превращаются в монстров.'),
#               'вид.30': ('. В одном из холодных кабинетов средь списанной мебели сидели четыре мужичка пролетарского ',
#                'вида',
#                ' и одна девушка (все колмогоровцы).'),
#               'вид.31': ('нужно о-очень быть подкованным в философии, чтобы она дошла в таком ',
#                'виде',
#                '.'),
#               'вид.32': ('С ', 'виду', ' парень как парень...'),
#               'вид.33': ('собою о разных материях, между прочим и о птице фениксе, о ее ',
#                'виде',
#                ', свойстве, а особливо, для чего она столь редко видима?'),
#               'вид.34': ('В картине «Бегство мистера Мак-Кинли» есть крохотный эпизод, КОГДА развратного ',
#                'вида',
#                ' субъект предлагает Банионису двух нимфеток.'),
#               'вид.35': ('области -3 - +2°) В среду облачные поля начнут редеть и осадки приобретут ',
#                'вид',
#                ' кратковременных снежных зарядов.'),
#               'вид.36': ('Использую вместо подушки, – с самым серьезным ',
#                'видом',
#                ' доказывает Вагнер.'),
#               'вид.37': ('Здесь и внушительного ',
#                'вида',
#                '"старички", ровесники 44-летнего Кинчева, но молодых - большинство.'),
#               'вид.38': ('У машин необычайно добротный ',
#                'вид',
#                ' и на дверцах толстые, аккуратные цифры: Д-3-54-27, Д-3-'),
#               'вид.39': ('против грота, построены были большие готические ворота, фантазия, придуманная собственно для украшения ',
#                'вида',
#                '.'),
#               'вид.40': ('... Своего рода советская Рублевка - невиданный по тем временам комфорт, консьержи в подъездах,',
#                'виды',
#                ' на Кремль через реку, фонтаны во дворе.'),
#               'вид.41': ('появилась табличка «Молитвенная комната «Ислам АГ», под которой была наклеена картинка с ',
#                'видом',
#                ' Мекки.'),
#               'вид.42': ('Появился новый ',
#                'вид',
#                ' компьютерного червя, который использует имя известной американской актрисы Дженнифер Лопес.'),
#               'вид.43': ('них будет служить в сухопутных войсках, треть - во внутренних, остальные - в других ',
#                'видах',
#                ' вооруженных сил.'),
#               'вид.44': ('Он долго перечислял достижения на поприще разработки новых ',
#                'видов',
#                ' вооружений.'),
#               'вид.45': ('ЗА - Теоретически появление нового ',
#                'вида',
#                ' вируса гриппа возможно.'),
#               'вид.46': ('Зато этому национальному духу издревле был свойственен третий, особый ',
#                'вид',
#                ' материализма, который радикально отличается от двух первых и который я для краткости'),
#               'вид.47': ('Но что такое человек, даже в самом лучшем его ',
#                'виде',
#                '?'),
#               'вид.48': ('Междугородный телефон, хоть пока еще не ',
#                'вид',
#                ' транспорта, но тоже приводится в действие только хитроумным жетоном местной заточки, который'),
#               'вид.49': ('для йоги Lululemon и Центральный парк, где американцы зачастую практикуют занятия восточными ',
#                'видами',
#                ' спорта.'),
#               'вид.50': ('Скорее, больше: похоже, этот ',
#                'вид',
#                ' бизнеса становится все доходнее - открываются новые притоны, куда слетаются и новички, и'),
#               'вид.51': ('А от сего недостатка происходит, что все действия его восприяли ',
#                'вид',
#                ' произвола и вместо правильного суда подверглись сим странным, так сказать, пересудам, где'),
#               'вид.52': ('Многие из любомудрых три ',
#                'вида',
#                '[species] сотворенных духов поставляют: вид нижний, имеющий силу приводить вещество в способ,'),
#               'вид.53': ('Но есть такие ',
#                'виды',
#                ' услуг или деятельности, о которых необходимо заявлять.'),
#               'вид.54': ('гормонрецепторных взаимодействиях в культурах клеток насекомых in vitro, может служить критерием выявления ',
#                'видов',
#                ', у которых экдистероиды играют экорегуляторную роль.'),
#               'вид.55': ('во вредных и опасных условиях труда в 2010 году только в ведущих ',
#                'видах',
#                ' экономической деятельности (добыча полезных ископаемых, обрабатывающие производства, строительство, транспорт и связь) составили'),
#               'вид.56': ('Дело в том, что наша поправка в Закон "О лицензировании отдельных ',
#                'видов',
#                ' деятельности" не несет запрета на игорный бизнес, как кто-то пытается толковать нашу'),
#               'вид.57': ('Последний ',
#                'вид',
#                ' договоров хотя и имеет письменную форму, по своему определению не содержит положений,'),
#               'вид.58': ('Выводы комиссии шокировали страховщиков, ожидавших введения нового обязательного ',
#                'вида',
#                ' страхования, сопоставимого по сборам с "автогражданкой".'),
#               'вид.59': ('°C. Белое море, несмотря на северное расположение и суровый климат, для арктических ',
#                'видов',
#                '-- самый южный край ареала, их тут совсем немного, и сосредоточены они в'),
#               'вид.60': ('ДРУЖЕСКИЙ ОБМЕН УДАРАМИ В ныне действующем Уголовном кодексе РФ предусматривается несколько ',
#                'видов',
#                ' освобождения от уголовной ответственности.'),
#               'вид.61': ('Мы рассмотрим еще один ',
#                'вид',
#                ' передвижений -- «змеевидный» шаг.'),
#               'вид.62': ('Военно-морские силы (2 500 человек) являются самостоятельным ',
#                'видом',
#                ' вооруженных сил.'),
#               'вид.63': ('Дифференциация жанров и ',
#                'видов',
#                ' танца продолжится, рискуя дойти до абсурда.'),
#               'вид.64': ('самого начала задумывался как место, где под одной крышей будут существовать разные ',
#                'виды',
#                ' искусства - от театра до современного танца, музыки и кино.'),
#               'вид.65': ('Раньше это было всего лишь хобби, теперь это мой основной ',
#                'вид',
#                ' деятельности.'),
#               'вид.66': ('Новый ',
#                'вид',
#                ' мошенничества приносит хакерам миллионы, а поймать злоумышленников практически невозможно.'),
#               'вид.67': ('степени зависит область обитания животных, их видовой ареал, так как у каждого ',
#                'вида',
#                ' есть свой температурный диапазон, за пределами которого теряется способность к размножению.'),
#               'вид.68': ('соревнований, так же как и остальные судьи, за исключением старшего судьи по ',
#                'виду',
#                ' и комендантской команды, должны являться к месту соревнований за час до первого'),
#               'вид.69': ('В СЕВЕРНЫЙ - НА ЭКСПРЕСС-ЭЛЕКТРИЧКЕ Именно такой ',
#                'вид',
#                ' транспорта появится в одном из отдаленных районов Москвы.'),
#               'вид.70': ('. Но вряд ли кто-то будет спорить с тем, что футбол в России –',
#                'вид',
#                ' спорта номер один.'),
#               'вид.71': ('Все остальные ',
#                'виды',
#                ' информационных работ, хотя и имеют самостоятельный характер, но могут также рассматриваться как'),
#               'вид.72': ('Радикальным же средством явилось бы полное запрещение всех ',
#                'видов',
#                ' любительской охоты.'),
#               'вид.73': ('Один ',
#                'вид',
#                ' деревьев имеет плоды величиною с небольшую дыню.'),
#               'вид.74': ('В ней имеет место смешение этих двух ',
#                'видов',
#                ' пенсий, и указано 600 руб. вместо 168 руб. 47 коп. и'),
#               'вид.75': ('Несмотря на заверения продавцов этого ',
#                'вида',
#                ' растения, что монтбреция зимует в грунте, опыт показывает: даже укрытые, большинство сортов'),
#               'вид.76': ('От других ',
#                'видов',
#                ' M.variabilis отличается присутствием резкого шаровидного расширения на эпипрокте самца.'),
#               'вид.77': ('телефонов написали FCC письмо, призвав не торопиться, отметив, в частности, что новый ',
#                'вид',
#                ' связи может вызвать помехи.')},
#              'винт': {'винт.1': (', но почти такие, как у фузей; дуло одного пистолета имеет около себя ',
#                'винт',
#                ', а другой пистолет имеет сквозь приклад до заряду круглую диру и в'),
#               'винт.2': ('в вещь, которую Иван со скрежетом крутил двумя руками -- корпус к себе,',
#                'винт',
#                ' от себя, -- точно пытался развести, разъять будущее и прошлое, чтобы последнее, бросившись'),
#               'винт.3': (', ', 'винт', '-то откуда?'),
#               'винт.4': ('Как новый ',
#                'винт',
#                ' по заранее взятой мерке, и я вошел в аппарат и принял детское'),
#               'винт.5': ('Дельцы то же, что ',
#                'винты',
#                ', болты, рычаги и пружины в машине.'),
#               'винт.6': ('А для хирургических ',
#                'винтов',
#                ' использовать крошку из искусственно выведенных наноалмазов.'),
#               'винт.7': ('и склейки корпуса бокса крепится ',
#                'винтом',
#                ' рейка с кадрирующей рамкой, визиром и винтом с резиновой головкой, который позволяет прижать бокс к стеклу маски, что обеспечит «'),
#               'винт.8': ('2,14 м2, длина 3,40 м, высота 0,91 м, диаметр ',
#                'винта',
#                ' 0,66 м, масса пустого 91,0 кг, максимальная масса топлива 28,'),
#               'винт.9': ('; его станина прикреплена к передней панели также двумя ',
#                'винтами',
#                ' и шляпки обоих винтов, дабы не портили вида, закрываются -- одна шкалою, другая -- надписью «настройка».'),
#               'винт.10': ('Сама панель укрепляется на ',
#                'винтах',
#                ' к боковым стенкам ящика.'),
#               'винт.11': ('А то мелкие шайбы, прокладки и ',
#                'винты',
#                ' так и тянет смыться от домашних мастеров в канализацию.'),
#               'винт.12': ('Для сборки осветителя панель с электронной схемой крепят тремя ',
#                'винтами',
#                '.'),
#               'винт.13': ('Коньки в то время были деревянные, и только самое лезвие и ',
#                'винт',
#                ', который ввинчивался в каблук сапога, были стальные.'),
#               'винт.14': ('при протезировании и лечении переломов костей алмазную крошку Для современных протезов и ',
#                'винтов',
#                ', скрепляющих сломанные кости, используется сверхпрочная пластмасса: протезы и винты из такого материала'),
#               'винт.15': ('Бортика крышки укрепляются 3 ',
#                'винтами',
#                ' на доске.'),
#               'винт.16': ('Предварительно закрепив ее на данном расстоянии ',
#                'винтом',
#                ', ножницы перемещают таким образом, чтобы ролик катился по краю материала -- от него'),
#               'винт.17': ('Размеры же ',
#                'винтов',
#                ', гаек и шайб под имеющиеся уже стандарты не подходят и имеют специальные'),
#               'винт.18': ('К слову, при сборке любых кранов и сантехнических устройств зажимные ',
#                'винты',
#                ' нужно заранее смазать маслом: потом не будет проблем при ремонте.'),
#               'винт.19': ('-ка я доверну, -- сказал я, взял у него отвертку и навалился на ',
#                'винт',
#                '.'),
#               'винт.20': ('под избыточным давлением; ремонт вентиляторов электродвигателя и его кожуха; установку недостающих болтов,',
#                'винтов',
#                ' и гаек.'),
#               'винт.21': ('с просверлённым в ручке отверстием под вороток поможет выкрутить присохшие или приржавевшие ',
#                'винты',
#                ' и шурупы.'),
#               'винт.22': ('Кольцо надевается на объектив и крепится к нему тремя ',
#                'винтами',
#                ' М3.'),
#               'винт.23': ('С их помощью удаётся разобрать резьбовое соединение с «прикипевшими»',
#                'винтом',
#                ' и гайкой.'),
#               'винт.24': ('Захлопнут гроб крышкой, и завинтит ее вечным ',
#                'винтом',
#                ' вечного цеха мастер, гробовщик Иван Софронов, и опустят тело в подземные жилища...'),
#               'винт.25': ('1 мм) и путем передвигания вибратора и контактного ',
#                'винта',
#                ', добиваются отсутствия искры в контактах.'),
#               'винт.26': ('Это простой ременный пояс с гайкой и ',
#                'винтом',
#                ' на концах.'),
#               'винт.27': ('Пускай себе капитан требует сколько ему угодно ',
#                'винтов',
#                ', блоков, и пр., и пр. «Мое дело, -- скажет себе контора, -- мое'),
#               'винт.28': ('им. Ворошилова С. В. Нисс прочел лекцию на тему «О вихревой нарезке ',
#                'винтов',
#                '», в которой он изложил теоретические основы этого процесса, а стахановец Е. А.'),
#               'винт.29': ('должна быть немного меньше диаметра шляпки контакта, и отверстия соответствовали толщине его ',
#                'винта',
#                '.'),
#               'винт.30': ('То было большое, качающееся на ',
#                'винтах',
#                ', трюмо.'),
#               'винт.31': ('',
#                'Винт',
#                ' b1 служит для укрепления пружины якоря на скобе,винт же d2 -- для регулировки расстояния между якорем и электромагнитом.'),
#               'винт.32': ('кают, полы и потолки, тогда как качка корежила, гнула и расшатывала все ',
#                'винты',
#                ', болты, скрепы и заклепки.'),
#               'винт.33': ('есть все элементы, указывающие, что рабочий остался человеком, а не превратился в ',
#                'винт',
#                ' сложного механизма.'),
#               'винт.34': ('Сын у нее на глазах пробует ',
#                'винты',
#                ', которыми замок крепится.'),
#               'винт.35': ('Тогда поднимаем заднее сиденье и, отвернув два ',
#                'винта',
#                ', снимаем лючок.'),
#               'винт.36': (', да и долой, а товарищи мои, моряки, начали вглядываться во всякую гайку,',
#                'винт',
#                '.'),
#               'винт.37': ('Подвинчивая ',
#                'винт',
#                ' V, можно было деформировать раму и таким образом регулировать длину первичной искры ('),
#               'винт.38': ('• Тряпочка • Пила • Сверло диаметром 3 мм •',
#                'Винты',
#                ' такого же диаметра • Кисточки (широкая и узкая) КАК ЭТО ДЕЛАЕТСЯ Если в'),
#               'винт.39': ('купил возле метро, без усилий встала в паз, и он закрепил ее ',
#                'винтом',
#                '.'),
#               'винт.40': ('Корабль этот имеет паровую машину и винтовой движитель (след ',
#                'винта',
#                ' за кормой).'),
#               'винт.41': ('Сложные гидротехнич . сооружения ( напр ., архимедов ',
#                'винт',
#                '), требования военной техники ( метательные машины Архимеда ), запросы мореплавания ( исследования Архимеда о равновесии'),
#               'винт.42': ('Под кабиной беспрерывно и стремительно вращался архимедов ',
#                'винт',
#                ', по которому скользила слегка дымящаяся серовато-зеленая масса.'),
#               'винт.43': ('От встречного потока воздуха завертелся ',
#                'винт',
#                ', горючее поступило в мотор, который, фыркая и чихая, заработал.'),
#               'винт.44': ('Она подается вперед и по архимедову ',
#                'винту',
#                ' равномерно разносится по всей площади будущего шоссе.'),
#               'винт.45': ('на обоих судах работали полным ходом, и корвет и клипер, буравя своими ',
#                'винтами',
#                ', шли узлов по семи, по восьми, направляясь в Нагасаки, до которого было'),
#               'винт.46': ('управления в полете на концах поперечной фермы имелись два дополнительных вертикально расположенных ',
#                'винта',
#                '.'),
#               'винт.47': ('обманываясь, Потокин вскакивал на крыло, нырял с головой в жаркую, подрагивающую, обдуваемую ',
#                'винтом',
#                ' кабину новичка -- проверить соединительный кран, триммер, сбрасыватель, то есть сделано ли все,'),
#               'винт.48': ('и все разом, включая «Самсона», петергофские фонтаны от продолжающих работать трех огромных ',
#                'винтов',
#                '.'),
#               'винт.49': ('Спереди и сзади между туннельными ',
#                'винтами',
#                ' следует расположить два инерционных двигателя.'),
#               'винт.50': ('воздушных ',
#                'винтов',
#                ' определенных размеров, и вес грузов, которые могли бы быть этими винтами подняты.'),
#               'винт.51': ('Вследствие трения о воду лопастей ',
#                'винта',
#                ' вода нагревается .'),
#               'винт.52': ('«Константин Бондаренко» намотал на ',
#                'винт',
#                ' металлический трос и застрял на расстоянии 74 км от берега в районе'),
#               'винт.53': ('ТВД Дженерал Электрик СТ7-9В (2x1870 л.с.) с четырехлопастными реверсивными воздушными ',
#                'винтами',
#                ' изменяемого шага, диаметр винтов -- 3,35 м.'),
#               'винт.54': ('Развели пары,',
#                'винт',
#                ' почти не действовал, -- так сильно было волнение.'),
#               'винт.55': ('не может отразиться в воде, то-и-дело рассекаемой ударами весел, пароходных ',
#                'винтов',
#                ', глубокими, острыми килями турецких фелюг или других парусных судов, бороздящих по всем'),
#               'винт.56': ('В случае отказа двигателя ',
#                'винты',
#                ' должны были быть переведены на режим авто ротации для уменьшения скорости снижения.'),
#               'винт.57': ('То есть у него есть большой несущий ',
#                'винт',
#                ' сверху и маленький толкающий сзади.'),
#               'винт.58': ('-- От ',
#                'винта',
#                ', -- громко сказал он, дождавшись сигнала, что разряд набран и прибор готов работе.'),
#               'винт.59': ('-',
#                'Винт',
#                ' вертолета оторвался и отлетел в сторону, - рассказывает свидетель ЧП рыбак Александр МАСЛОВ.'),
#               'винт.60': ('. Встречаются и трудности помельче: штормы, акулы, тина, зыбкое дно, отходы промышленных предприятий,',
#                'винты',
#                ' кораблей, крутые берега, коряги, омуты, крокодилы...'),
#               'винт.61': ('Едва нырнули метров на 17, как над головой - шум ',
#                'винтов',
#                ' эсминца.'),
#               'винт.62': ('Многие японские авиационные моторы и воздушные ',
#                'винты',
#                ' были изготовлены по американским чертежам, приобретенным по лицензии в довоенные годы...'),
#               'винт.63': ('острая корма - особенность конструкции броненосца типа «монитор» - плюс вспомогательный румпель, специфической формы ',
#                'винты',
#                ', иллюминаторы.'),
#               'винт.64': ('Над ним, сердито ревя ',
#                'винтами',
#                ', треща, озаряясь вспышками, закружились корабли.'),
#               'винт.65': ('не узнал, ибо в тот самый момент то ли кубинская субмарина рубанула ',
#                'винтом',
#                ' податлантический телефонный кабель, то ли (что вероятней) я просто ногой задел розетку...'),
#               'винт.66': ('Преимущество в боевой живучести обеспечивается и отсутствием рулевого ',
#                'винта',
#                ' и его приводов, поражение которого на вертолете с'),
#               'винт.67': ('Сливочный ',
#                'винт',
#                ' сепаратора должен быть установлен таким образом, чтобы из 5-6 частей молока'),
#               'винт.68': ('Ядерная силовая установка, приводящая в движение один гребной ',
#                'винт',
#                ', позволит лодке развивать скорость в надводном положении до 15 узлов, а в'),
#               'винт.69': ('12 т, а в высоту больше 5 м, так как имеет два ',
#                'винта',
#                '.'),
#               'винт.70': ('упал в двух километрах от базы), а по внезапно прекратившемуся кудахтанью его ',
#                'винтов',
#                '.'),
#               'винт.71': (', с головой, и по наклонной линии направился кверху работая хвостом, как огромным ',
#                'винтом',
#                '.'),
#               'винт.72': ('Машина приводила в действие трехлопастный воздушный ',
#                'винт',
#                ' 11 футов в диаметре, делавший 110 оборотов в минуту.'),
#               'винт.73': (', Изменение подъемной силы, а также продольно-поперечное управление осуществлялись изменением общего шага ',
#                'винтов',
#                '.'),
#               'винт.74': ('По мнению следователей, вертолет снизился до опасной высоты и зацепил ',
#                'винтом',
#                ' склон горы Черная или попал в порыв сильного бокового ветра.'),
#               'винт.75': ('Неприметная, чуть выше колена ростом, чем-то похожая на гребной ',
#                'винт',
#                ' небольшого корабля.'),
#               'винт.76': ('изменяемого шага, диаметр ',
#                'винтов',
#                ' -- 3,35 м.'),
#               'винт.77': ('Основными особенностями машины является отсутствие хвостового ',
#                'винта',
#                ' и модульная компоновка.'),
#               'винт.78': ('По бокам гондолы приделаны два ',
#                'винта',
#                ', напоминающие уши.'),
#               'винт.79': ('Диаметр несущего ',
#                'винта',
#                ' 13,00 ; длина фюзеляжа 8,05 м; длина вертолета с вращающимися винтами'),
#               'винт.80': ('стопора находятся на гребных ',
#                'винтах',
#                ', а это может вызвать неожиданную работу гребных винтов и привести к несчастным случаям.'),
# ...
#                'штампом',
#                ' магазина и подписью продавца с указанием даты продажи.'),
#               'штамп.5': ('Утечка документа (кстати, с ',
#                'штампом',
#                '«Секретно - не копировать») случилась в ходе расследования дела двоих демонстрантов.'),
#               'штамп.6': ('раз проверил у Артема и Ульмана документы, и выдал им бумажки со ',
#                'штампом',
#                '«Временная регистрация -- транзит» и датой.'),
#               'штамп.7': ('Тем, кто получил такой ',
#                'штамп',
#                ', Ю. Ивашкин рекомендует обратиться в свои ОВД за проставлением штампа, соответствующего инструкции.'),
#               'штамп.8': ('перед окопом, кинул товарищам пачку папирос и Рощину передал записку со свежесмазанным ',
#                'штампом',
#                ': «Ожидайте, пришлю.'),
#               'штамп.9': ('паспортная книжка, проездными визами всех коллективов, с которыми я работал; каждая виза -',
#                '-штам',
#                'п той или иной горечи, того или иного непонимания.'),
#               'штамп.10': ('Второй законный тип семьи -- самбо -- не предполагает ',
#                'штампа',
#                ' в паспорте и'),
#               'штамп.11': ('Процедура «отметки» была, казалось бы, несложна.',
#                'Штамп',
#                ' с датой на нашем волчьем билете, заменяющем паспорт, и птичка в личной'),
#               'штамп.12': ('Отцом тогда будет спермодонор.',
#                'Штамп',
#                ' в паспорте у нее не спросят и ребенка в роддоме не заберут.'),
#               'штамп.13': ('В течение 3 дней после появления в паспорте ',
#                'штампа',
#                ' РВП нужно оформить в паспортно-визовом отделении ОВД регистрацию по месту временного'),
#               'штамп.14': ('библиотечные ',
#                'штампы',
#                ' с книг телефон Гы, ставлю эксклюзивные на Ваш выбор библиотечные штампы на книги! )))) Ставлю временные штампы и печати любых цветов в старые книги.'),
#               'штамп.15': ('-- Видишь, какой ', 'штамп', ', ого-го!'),
#               'штамп.16': ('Они уничтожают паспорта "гостей", вырывают странички, где стоит ',
#                'штамп',
#                ' о пересечении госграницы, чтобы нельзя было установить, когда, в какое время и'),
#               'штамп.17': ('Главным условием этого конкурса было... отсутствие ',
#                'штампа',
#                ' в паспорте о прописке.'),
#               'штамп.18': ('',
#                'Штамп',
#                ': «Королевская шведская миссия» (на шведском языке).'),
#               'штамп.19': ('Поднял рубаху, показал рубцы: -- Вот, глядите,',
#                'штампы',
#                '-- проверенный...'),
#               'штамп.20': ('Появились уже отдельные особи, у которых ',
#                'штампы',
#                ' в паспортах ставить некуда.'),
#               'штамп.21': ('Точнее про то, что к ',
#                'штампу',
#                ' в паспорте нельзя относиться так трагично.'),
#               'штамп.22': ('только удивленно смотрел: они же прежде всего просмотрели паспорта и наверняка видели ',
#                'штампы',
#                ' о регистрации брака.'),
#               'штамп.23': ('Аги и всего Забайкалья, под которым он и сам с удовольствием ставит ',
#                'штамп',
#                '"Выполнено" - это восстановление Новоорловского ГОКа.'),
#               'штамп.24': ('Олег полистал паспорт и обнаружил еще один ',
#                'штамп',
#                ', паспортного стола.'),
#               'штамп.25': ('в Москве, недостаточно -- необходимо иметь справку о регистрации по месту пребывания или ',
#                'штамп',
#                ' в паспорте о регистрации по месту жительства в г. Москве.'),
#               'штамп.26': ('- У нас привыкли, что билет - это несколько страниц со ',
#                'штампами',
#                ', и при покупке электронного билета люди боятся, что их просто надули и'),
#               'штамп.27': (', чтобы устроиться в гостиницу, получить ордер на квартиру - надо показать паспорт со ',
#                'штампом',
#                ' о регистрации, сейчас такого нет.'),
#               'штамп.28': ('Не допускается и переправлять цифры или буквы в «неправильном»',
#                'штампе',
#                ', даже заверяя их печатью ОВД.'),
#               'штамп.29': ('новой «корочкой» гражданина России получают и вырезанную из старого паспорта бумажку со ',
#                'штампом',
#                ', где как раз указаны их группа крови и резус-фактор.'),
#               'штамп.30': ('Он у меня был просрочен, однако в паспорте стоит ',
#                'штамп',
#                ' и есть пояснение, что новую карточку мне должны выслать в течение двух'),
#               'штамп.31': ('-- Груба показывает бумагу со ',
#                'штампом',
#                ': «Ваше письмо от 12 февраля с. г. относительно организации поиска Янтарной'),
#               'штамп.32': ('Все было в полном порядке:',
#                'штампы',
#                ', подписи, печати, но Размётнов долго и придирчиво рассматривал предъявленные ему документы и'),
#               'штамп.33': ('Дата поставлена сегодняшняя, печать и ',
#                'штамп',
#                '-- подлинные, в доказательство чего Антонина Синицына стянула с себя платье и обмахалась'),
#               'штамп.34': ('И ',
#                'штамп',
#                ' в паспорта: «Обязателен к уплате алиментов».'),
#               'штамп.35': ('лет, и я получаю от этого типа новогоднюю открытку с идиотским почтовым ',
#                'штампом',
#                ', на котором изображено крылатое чудище.'),
#               'штамп.36': ('Все прелести сразу же за маршем Мендельсона и ',
#                'штампом',
#                ' в паспорте.'),
#               'штамп.37': ('совали друг другу под нос свои паспорта, раскрытые на страничке, где красовались ',
#                'штампы',
#                ' о браке со Скворцовым Геннадием Степановичем.'),
#               'штамп.38': ('поспешили за свидетельствами о расторжении брака, чтобы в новом паспорте не было ',
#                'штампа',
#                ' о регистрации.'),
#               'штамп.39': ('Лишь со второго раза, проставив все ',
#                'штампы',
#                ' и печати, Корсунскому удалось убедить суд приобщить к делу акты, зафиксировавшие нарушения -'),
#               'штамп.40': ('Это могут быть: паспорт со ',
#                'штампом',
#                ' о прописке, свидетельство о временной регистрации, соответствующие справки, выданные ОВД.'),
#               'штамп.41': ('Эти затертые ',
#                'штампы',
#                ' не способны описать того, что творится в городе во время финала.'),
#               'штамп.42': ('путевка и еще несколько совсем уж мелких квитков, но все с печатями,',
#                'штампами',
#                ' и подписями.'),
#               'штамп.43': ('Фельдшерица спала на кушетке, укрывшись серым байковым одеялом с казенным ',
#                'штампом',
#                '.'),
#               'штамп.44': ('. "Печати и ', 'штампы', '".'),
#               'штамп.45': ('BODIES WITHOUT ORGANS Prototype (Capitol) На эту пластинку впору ставить ',
#                'штамп',
#                ': «Сделано для продажи в странах СНГ».'),
#               'штамп.46': ('внутренних дел в паспорте гражданина РФ на странице 19 с помощью оттиска ',
#                'штампа',
#                ' по форме № 20П или путем внесения штампа по форме № 21П. Данные штампы'),
#               'штамп.47': ('Еще не затвердевшую стеклянную массу помещают в специальные ',
#                'штампы',
#                ', где изделия спрессовывают по форме, принятой для огранки имитируемых камней.'),
#               'штамп.48': ('. Пожалуйста, кто знает, как можно удалить ',
#                'штампы',
#                ' с книги?'),
#               'штамп.49': ('обработке ', 'штампов', ' и пресс-форм.'),
#               'штамп.50': ('Я против ',
#                'штампа',
#                '«государственное плохо -- частное хорошо».'),
#               'штамп.51': ('Между тем подобные ',
#                'штампы',
#                ', конечно, опасны, как и любой самообман.'),
#               'штамп.52': ('Бытовые довоенные зарисовки выглядят в картине ',
#                'штампами',
#                ', любовные интриги героини - плоскими.'),
#               'штамп.53': ('Это колорит дурного вкуса и дурного ',
#                'штампа',
#                ', который явно чужероден театральности вахтанговцев.'),
#               'штамп.54': ('место рождения (много солнца, моря и пищи для размышлений) или это -- очередной ',
#                'штамп',
#                ', а штампов Татьяна Соломатина не любит.'),
#               'штамп.55': ('В ГАИ стало привычным ',
#                'штампом',
#                ' перекладывать вину за все, во-первых, на "плохих водителей" - лихачей, пьяниц за рулем,'),
#               'штамп.56': ('Просто годы чиновничьего груза прибили его, появилась куча ',
#                'штампов',
#                ' и шаблонов.'),
#               'штамп.57': ('Он часто просил меня: "Смотри, чтоб я ненароком какой-нибудь свой ',
#                'штамп',
#                ' на экран не вытащил".'),
#               'штамп.58': ('услышали совсем не то, что для нас готовилось, а лишь стерилизованный набор ',
#                'штампов',
#                ', который если и не поможет чему-то, то по крайней мере не навредит'),
#               'штамп.59': ('В нем есть слова, которые обычно сливаются в стершийся образ-',
#                'штамп',
#                ': Прабабка в черном, чопорная ночь, Приди…'),
#               'штамп.60': ('Ложь обросла своим языком, своим жаргоном; своим кодовым ',
#                'штампом',
#                ': «семимильными шагами», «весь народ, как один», «мы заверяем».'),
#               'штамп.61': ('Его подход - это просто уход от ', 'штампов', '.'),
#               'штамп.62': ('нечто нестандартное - публика оставалась холодной, как только она обращалась к пошловатым эстрадным ',
#                'штампам',
#                '- аудитория взрывалась раскатами смеха.'),
#               'штамп.63': ('Вы знаете, что это кончается ',
#                'штампом',
#                ' и ремеслом, -- остановил его Торцов.'),
#               'штамп.64': ('У нас как бы не очень для нашего слуха этот ',
#                'штамп',
#                ' работает.'),
#               'штамп.65': (', дает ',
#                'штамп',
#                ' только себя одной, -- но себя, понимаемой множественно и потому являющейся штампом всех «себя» одинаковой метафоры.'),
#               'штамп.66': ('И даже ', 'штампам', '.'),
#               'штамп.67': ('способностей обычно устанавливаются годам к 14, а остальное это уже наросты и ',
#                'штампы',
#                '— так называемый опыт.'),
#               'штамп.68': ('-иностранца, пейдодна-пейдодна-пейдодна, к нам приехал наш любимый) со временем сделались ',
#                'штампом',
#                ' публицистических самопокаянных передач.'),
#               'штамп.69': ('местами неряшлив (9), в описаниях имеются пробелы (10), сплошь и рядом наличествуют ',
#                'штампы',
#                ', банальности и другие закавыки (11), но чего еще требовать от скромного самоучки,'),
#               'штамп.70': ('',
#                'Штамп',
#                '«они были первыми» идеален для Людмилы Белоусовой и Олега Протопопова.'),
#               'штамп.71': ('Нет ничего глупее этих ',
#                'штампов',
#                ', которые наверняка отложатся в сознании по случаю первого в истории прорыва Португалии'),
#               'штамп.72': ('Мужская рубашка на женском теле -',
#                '-штамп',
#                'ы и стереотипы.'),
#               'штамп.73': ('Если отходить от энхаэловских ',
#                'штампов',
#                ', скорее всего Овечкин дернул левую руку в драке с кем-то из игроков «'),
#               'штамп.74': ('Ведь словесные ',
#                'штампы',
#                ' выработаны с древних времен хитроумным сословием чиновников для той специфической формы обмана,'),
#               'штамп.75': ('Так, З. Компанеец в «Песне женщин», стремясь отойти от ',
#                'штампа',
#                ' ладово-гармонических приемов, избрал на редкость безвкусный гармонический план (в основной тональности'),
#               'штамп.76': ('нередко зачисляли в драмоделы елизаветинских времен, писавшего за несколько фунтов пьесы, согласно ',
#                'штампам',
#                ' своего времени.'),
#               'штамп.77': ('О мир, твои прекрасны ',
#                'штампы',
#                ': То свет с небес, то свет от лампы, То свет от белого'),
#               'штамп.78': (', и разборки в мужском коллективе (Андерсон снимает будни рабов-гладиаторов со всеми ',
#                'штампами',
#                ' американских фильмов про тюрьму), и браки по расчету (женитьба детей как выгодное'),
#               'штамп.79': ('Идея собрать все ',
#                'штампы',
#                ' попсы и романтических историй в одну кучу оказалась открытием сезона.'),
#               'штамп.80': ('Первые полчаса «Таймлесс» перебирает всевозможные ',
#                'штампы',
#                '.'),
#               'штамп.81': ('порождает своих монстров и своих ',
#                'штампов',
#                '?'),
#               'штамп.82': (', что наша публикация, как минимум, содержательней других, наполненных пустыми словесными фанфарами и ',
#                'штампами',
#                '.'),
#               'штамп.83': ('Однако после выступления Ленина (о ларинской фантазии)',
#                'штамп',
#                ' фантазера к нему пристал.'),
#               'штамп.84': ('Нормальный ',
#                'штамп',
#                ', мол, даже у иконных персонажей в исполнении этого актера было что-то человеческое...'),
#               'штамп.85': ('Есть такой расхожий ',
#                'штамп',
#                '— играть «Кушать подано!».'),
#               'штамп.86': ('',
#                'Штампы',
#                ' аргументировались стереотипами, а стереотипы --штампами.'),
#               'штамп.87': ('Далеко еще не изжиты рапмовскне ',
#                'штампы',
#                ', даже такие примитивные, как обязательный двухдольный размер, стандартно-маршевые ритмические фигуры, восходящие'),
#               'штамп.88': ('Адаптация «лесных» Официальные же власти пытаются действовать старыми ',
#                'штампами',
#                ' уговоров.'),
#               'штамп.89': ('коллектива "Блестящие", даже облаченные в военные гимнастерки, не смогли полностью освободиться от ',
#                'штампов',
#                ' исполнения, присущих нынешней попсе.'),
#               'штамп.90': ('роль личности всячески ущемляется, так как она не вписывается в контексты привычных ',
#                'штампов',
#                ' и расхожих клише, на то она и личность.'),
#               'штамп.91': ('В Пятой Малера Федосеев предложил далекую от привычных ',
#                'штампов',
#                ', но весьма убедительную трактовку довольно часто исполняемого произведения.'),
#               'штамп.92': ('дурак, но партию свою отрабатывал точно, по установившимся ',
#                'штампам',
#                ', а коль скоро штампы создались, надо было доводить их до совершенства.'),
#               'штамп.93': ('Отсюда мораль -- пишет по ',
#                'штампу',
#                ', думать нельзя.'),
#               'штамп.94': (', что актер должен иметь пять ',
#                'штампов',
#                '-клише "плохой" и семь или десять штампов"хороший".'),
#               'штамп.95': ('сегодняшний день в системе негосударственного пенсионного обеспечения и пенсионных накоплений еще остаются ',
#                'штампы',
#                ' мышления распределительной пенсионной системы, в основе которой принципы собрать, не потерять и'),
#               'штамп.96': ('молиться на Брукхаймера… …В «Пираты Карибского моря-3» сценаристы затащили все приключенческие ',
#                'штампы',
#                ', которые не успели переработать в предыдущих двух фильмах.')}})

# %%
pos = df['positions'][0]
start, end = map(int, pos.split(',')[0].split('-'))

# %%
s = start - 90
e = end - 90

# %%
next(gen)
# Out:
# ('на обозной повозке, я приближался к своей батарее, расположенной где-то в степной ',
#  'балке',
#  '.',
#  'балка.83')

# %%
obj = next(gen)
obj
# Out:
# (['В',
#   'картине',
#   'Бегство',
#   'мистера',
#   'Мак-Кинли',
#   'есть',
#   'крохотный',
#   'эпизод',
#   'КОГДА',
#   'развратного'],
#  'вида',
#  ['субъект', 'предлагает', 'Банионису', 'двух', 'нимфеток'])

# %%
df.he
# Out:
#     context_id   word  gold_sense_id  predict_sense_id       positions  \
# 0            1  балка              1               NaN           90-95
# 1            2  балка              1               NaN           69-74
# 2            3  балка              1               NaN         115-122
# 3            4  балка              1               NaN           85-91
# 4            5  балка              1               NaN           66-71
# ..         ...    ...            ...               ...             ...
# 95          96  балка              2               NaN           87-92
# 96          97  балка              2               NaN  99-104,116-121
# 97          98  балка              2               NaN           69-74
# 98          99  балка              2               NaN           78-83
# 99         100  балка              2               NaN           61-66
#
#                                               context
# 0   маленькой комнаты. Он был очень высок, наклони...
# 1   Пантюхин в Склифе сейчас. Он выползти на улицу...
# 2   равнозначно обеспечивает и меланхоличную езду....
# 3   верхняя часть закрыта, замкнута, многократно о...
# 4   по телевизору: наши гол забили, я вскочил от р...
# ..                                                ...
# 95  числом отношение пройденного пути к остающемус...
# 96  , продолжая удерживать Павлоград. Штаб группы ...
# 97  и грибами. Этого в лесу вдоволь. Пять дней Тат...
# 98  быть сам Шамиль. Партия спустилась под гору и ...
# 99  в машину, хозяйка убежала в дом, а немцы, свер...
#
# [100 rows x 6 columns]

# %%
df_test = pd.read_csv('resources/russe-wsi-kit-fixed_datasets/data/main/bts-rnc/train.baseline-adagram.csv', sep='\t')

# %%
df_test[df_test.word == 'вид']
# Out:
#      context_id word  gold_sense_id  predict_sense_id positions  \
# 119         120  вид              1                 3     87-90
# 120         121  вид              1                 3     92-94
# 121         122  вид              1                 2     78-80
# 122         123  вид              1                 2     96-98
# 123         124  вид              1                 3   100-102
# ..          ...  ...            ...               ...       ...
# 191         192  вид              5                 4     95-97
# 192         193  вид              5                 3     81-85
# 193         194  вид              5                 4   102-105
# 194         195  вид              5                 4     81-85
# 195         196  вид              5                 1     86-88
#
#                                                context
# 119  смешения с Raffaello. Однако судебный спор «Ла...
# 120  дизельным двигателем и другими современными ме...
# 121  углубляются немцы в нашу страну, тем опаснее с...
# 122  - Остафьев отвечал с расстановкой, тоже, как и...
# 123  из методов определения координат этой точки. П...
# ..                                                 ...
# 191  Хлебные деревья распространены повсюду в тропи...
# 192  надбавок для самых нуждающихся пенсионеров. В ...
# 193  гладиолус"), выкапывают и хранят подобно луков...
# 194  субгенитальной пластинки этих самок была схода...
# 195  телефонов написали FCC письмо, призвав не торо...
#
# [77 rows x 6 columns]

# %%
'его в руки возьмет, тому он и служит, -- поучительно сказал Яков, закусив губу и натягивая на ногу сапог; он встал и, выставив ногу вперед, критически'[74:78]
# Out:
# 'губу'
